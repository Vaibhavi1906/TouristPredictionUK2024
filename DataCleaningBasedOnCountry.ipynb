# %%
import pandas as pd

# Load each relevant sheet
sheet12_df = pd.read_excel('TravelTrendsToUK.xlsx', sheet_name='12', skiprows=2)
sheet13_df = pd.read_excel('TravelTrendsToUK.xlsx', sheet_name='13', skiprows=2)

# %%
print("Column names in sheet 12:", sheet12_df.columns.tolist())

try:
    VisitsByCountry_df = sheet12_df.melt(id_vars=['Area of Residence', 'Country'], var_name='Year', value_name='Visits by Country')
    print(VisitsByCountry_df.tail())
    print("Data extraction successful.")
except KeyError as e:
    print(f"Column error: {e}")
except Exception as e:
    print(f"Unexpected error: {e}")
# Out:
# Column names in sheet 12: ['Area of Residence', 'Country', '2019', '2020', '2021', '2022', '2023', '2019 Q1', '2019 Q2', '2019 Q3', '2019 Q4', '2020 Q1', '2020 Q2', '2020 Q3', '2020 Q4', '2021 Q1', '2021 Q2', '2021 Q3', '2021 Q4', '2022 Q1', '2022 Q2', '2022 Q3', '2022 Q4', '2023 Q1', '2023 Q2', '2023 Q3', '2023 Q4']
#      Area of Residence                       Country     Year  \
# 1595   Other Countries                        Mexico  2023 Q4
# 1596   Other Countries  Other Central & Sth. America  2023 Q4
# 1597   Other Countries             Rest of the World  2023 Q4
# 1598   Other Countries         Total Other Countries  2023 Q4
# 1599       Total World                   Total World  2023 Q4
#
#      Visits by Country
# 1595             49000
# 1596             86000
# 1597                 0
# 1598           1688000
# 1599           9441000
# Data extraction successful.

# %%
print("Column names in sheet 13:", sheet13_df.columns.tolist())

try:
    SpendingByCountry_df = sheet13_df.melt(id_vars=['Area of Residence', 'Country'], var_name='Year', value_name='Spendings by Country')
    print(SpendingByCountry_df.tail())
    print("Data extraction successful.")
except KeyError as e:
    print(f"Column error: {e}")
except Exception as e:
    print(f"Unexpected error: {e}")
# Out:
# Column names in sheet 13: ['Area of Residence', 'Country', '2019', '2020', '2021', '2022', '2023', '2019 Q1', '2019 Q2', '2019 Q3', '2019 Q4', '2020 Q1', '2020 Q2', '2020 Q3', '2020 Q4', '2021 Q1', '2021 Q2', '2021 Q3', '2021 Q4', '2022 Q1', '2022 Q2', '2022 Q3', '2022 Q4', '2023 Q1', '2023 Q2', '2023 Q3', '2023 Q4']
#      Area of Residence                       Country     Year  \
# 1595   Other Countries                        Mexico  2023 Q4
# 1596   Other Countries  Other Central & Sth. America  2023 Q4
# 1597   Other Countries             Rest of the World  2023 Q4
# 1598   Other Countries         Total Other Countries  2023 Q4
# 1599       Total World                   Total World  2023 Q4
#
#      Spendings by Country
# 1595                   35
# 1596                   93
# 1597                    0
# 1598                 2489
# 1599                 7428
# Data extraction successful.

# %%
Country_df = pd.merge(VisitsByCountry_df, SpendingByCountry_df, on=['Area of Residence', 'Country', 'Year'], how='inner')
Country_df.tail()
# Out:
#      Area of Residence                       Country     Year  \
# 1595   Other Countries                        Mexico  2023 Q4
# 1596   Other Countries  Other Central & Sth. America  2023 Q4
# 1597   Other Countries             Rest of the World  2023 Q4
# 1598   Other Countries         Total Other Countries  2023 Q4
# 1599       Total World                   Total World  2023 Q4
#
#      Visits by Country Spendings by Country
# 1595             49000                   35
# 1596             86000                   93
# 1597                 0                    0
# 1598           1688000                 2489
# 1599           9441000                 7428

# %%
import numpy as np
# Ensure the columns 'Period' and 'Year' are treated as strings
Country_df['Year'] = Country_df['Year'].astype(str)


# Replace "Not available" and other placeholders with NaN for easier processing
Country_df.replace("Not available", pd.NA, inplace=True)

print(Country_df[Country_df['Year'] == '2020'][['Area of Residence','Country','Year','Visits by Country','Spendings by Country']])

# Save the updated data to a new CSV file
output_path = 'CountryBasedUpdated_TravelTrends.csv'
Country_df.to_csv(output_path, index=False)
# Out:
#     Area of Residence                       Country  Year Visits by Country  \
# 64      North America                        Canada  2020              <NA>
# 65      North America                           USA  2020              <NA>
# 66      North America           Total North America  2020           1171000
# 67             Europe                       Austria  2020              <NA>
# 68             Europe                       Belgium  2020              <NA>
# ..                ...                           ...   ...               ...
# 123   Other Countries                        Mexico  2020              <NA>
# 124   Other Countries  Other Central & Sth. America  2020              <NA>
# 125   Other Countries             Rest of the World  2020              <NA>
# 126   Other Countries         Total Other Countries  2020           1942000
# 127       Total World                   Total World  2020          11101000
#
#     Spendings by Country
# 64                  <NA>
# 65                  <NA>
# 66                  <NA>
# 67                  <NA>
# 68                  <NA>
# ..                   ...
# 123                 <NA>
# 124                 <NA>
# 125                 <NA>
# 126                 <NA>
# 127                 6210
#
# [64 rows x 5 columns]

# %%
# Ensure the 'Year' column is treated as a string
Country_df['Year'] = Country_df['Year'].astype(str)

def backward_fill_values(data, year_to_fill, quarters, column_to_fill):
    # Loop through each area of residence
    for area in data['Area of Residence'].unique():
        # Loop through each country within the area
        for country in data[data['Area of Residence'] == area]['Country'].unique():
            print(f"Processing Area of Residence: {area}, Country: {country}")

            for quarter in quarters:
                # Create the period to fill
                period_to_fill = f'{year_to_fill} {quarter}'
                next_year = str(int(year_to_fill) + 1)
                next_period = f'{next_year} {quarter}'

                # Get the value from the next period
                next_value = data.loc[
                    (data['Year'] == next_period) & 
                    (data['Area of Residence'] == area) & 
                    (data['Country'] == country), 
                    column_to_fill
                ].values

                # Ensure there's a value to backfill from the next period
                if len(next_value) > 0 and not pd.isna(next_value[0]):
                    data.loc[
                        (data['Year'] == period_to_fill) & 
                        (data['Area of Residence'] == area) & 
                        (data['Country'] == country), 
                        column_to_fill
                    ] = next_value[0]

                    print(f"Filled {period_to_fill} with {next_period} value: {next_value[0]}")

    return data

# Define the quarters and columns to fill
quarters_to_impute = ['Q1', 'Q2', 'Q3', 'Q4']
columns_to_impute = ['Visits by Country', 'Spendings by Country']

# Step 1: Apply the backward fill function for 2020
for column in columns_to_impute:
    Country_df = backward_fill_values(Country_df, '2020', quarters_to_impute, column)

# Step 2: Recalculate the yearly data for 2020 based on the filled quarters
for area in Country_df['Area of Residence'].unique():
    for country in Country_df[Country_df['Area of Residence'] == area]['Country'].unique():
        for column in columns_to_impute:
            # Filter the data for 2020 and the relevant quarters
            yearly_value = Country_df.loc[
                (Country_df['Year'].str.startswith('2020')) & 
                (Country_df['Area of Residence'] == area) & 
                (Country_df['Country'] == country) & 
                (Country_df['Year'].str.contains('Q')), 
                column
            ].sum()
            
            # Update the yearly row with the sum of quarters
            Country_df.loc[
                (Country_df['Year'] == '2020') & 
                (Country_df['Area of Residence'] == area) & 
                (Country_df['Country'] == country), 
                column
            ] = yearly_value

            print(f"Recalculated 2020 for {country} in {area}: {yearly_value}")

# Print the entire DataFrame after recalculating yearly data for 2020
print("After Recalculating - Entire DataFrame for 2020:")
print(Country_df[Country_df['Year'].str.startswith('2020')])

# Save the updated data to a new CSV file
output_path = 'CountryBasedUpdated_TravelTrends.csv'
Country_df.to_csv(output_path, index=False)
# Out:
# Processing Area of Residence: North America, Country: Canada
# Filled 2020 Q1 with 2021 Q1 value: 2000
# Filled 2020 Q2 with 2021 Q2 value: 4000
# Filled 2020 Q3 with 2021 Q3 value: 50000
# Filled 2020 Q4 with 2021 Q4 value: 72000
# Processing Area of Residence: North America, Country: USA
# Filled 2020 Q1 with 2021 Q1 value: 29000
# Filled 2020 Q2 with 2021 Q2 value: 47000
# Filled 2020 Q3 with 2021 Q3 value: 239000
# Filled 2020 Q4 with 2021 Q4 value: 348000
# Processing Area of Residence: North America, Country: Total North America
# Filled 2020 Q1 with 2021 Q1 value: 31000
# Filled 2020 Q2 with 2021 Q2 value: 51000
# Filled 2020 Q3 with 2021 Q3 value: 289000
# Filled 2020 Q4 with 2021 Q4 value: 421000
# Processing Area of Residence: Europe, Country: Austria
# Filled 2020 Q1 with 2021 Q1 value: 3000
# Filled 2020 Q2 with 2021 Q2 value: 4000
# Filled 2020 Q3 with 2021 Q3 value: 24000
# Filled 2020 Q4 with 2021 Q4 value: 25000
# Processing Area of Residence: Europe, Country: Belgium
# Filled 2020 Q1 with 2021 Q1 value: 2000
# Filled 2020 Q2 with 2021 Q2 value: 6000
# Filled 2020 Q3 with 2021 Q3 value: 33000
# Filled 2020 Q4 with 2021 Q4 value: 118000
# Processing Area of Residence: Europe, Country: Bulgaria
# Filled 2020 Q1 with 2021 Q1 value: 8000
# Filled 2020 Q2 with 2021 Q2 value: 3000
# Filled 2020 Q3 with 2021 Q3 value: 20000
# Filled 2020 Q4 with 2021 Q4 value: 26000
# Processing Area of Residence: Europe, Country: Czech Republic
# Filled 2020 Q1 with 2021 Q1 value: 1000
# Filled 2020 Q2 with 2021 Q2 value: 3000
# Filled 2020 Q3 with 2021 Q3 value: 20000
# Filled 2020 Q4 with 2021 Q4 value: 31000
# Processing Area of Residence: Europe, Country: Cyprus
# Filled 2020 Q1 with 2021 Q1 value: 2000
# Filled 2020 Q2 with 2021 Q2 value: 2000
# Filled 2020 Q3 with 2021 Q3 value: 11000
# Filled 2020 Q4 with 2021 Q4 value: 26000
# Processing Area of Residence: Europe, Country: Denmark
# Filled 2020 Q1 with 2021 Q1 value: 2000
# Filled 2020 Q2 with 2021 Q2 value: 4000
# Filled 2020 Q3 with 2021 Q3 value: 23000
# Filled 2020 Q4 with 2021 Q4 value: 72000
# Processing Area of Residence: Europe, Country: Finland
# Filled 2020 Q1 with 2021 Q1 value: 1000
# Filled 2020 Q2 with 2021 Q2 value: 1000
# Filled 2020 Q3 with 2021 Q3 value: 3000
# Filled 2020 Q4 with 2021 Q4 value: 12000
# Processing Area of Residence: Europe, Country: France
# Filled 2020 Q1 with 2021 Q1 value: 13000
# Filled 2020 Q2 with 2021 Q2 value: 24000
# Filled 2020 Q3 with 2021 Q3 value: 148000
# Filled 2020 Q4 with 2021 Q4 value: 493000
# Processing Area of Residence: Europe, Country: Germany
# Filled 2020 Q1 with 2021 Q1 value: 10000
# Filled 2020 Q2 with 2021 Q2 value: 19000
# Filled 2020 Q3 with 2021 Q3 value: 144000
# Filled 2020 Q4 with 2021 Q4 value: 217000
# Processing Area of Residence: Europe, Country: Greece
# Filled 2020 Q1 with 2021 Q1 value: 4000
# Filled 2020 Q2 with 2021 Q2 value: 4000
# Filled 2020 Q3 with 2021 Q3 value: 23000
# Filled 2020 Q4 with 2021 Q4 value: 41000
# Processing Area of Residence: Europe, Country: Hungary
# Filled 2020 Q1 with 2021 Q1 value: 1000
# Filled 2020 Q2 with 2021 Q2 value: 2000
# Filled 2020 Q3 with 2021 Q3 value: 18000
# Filled 2020 Q4 with 2021 Q4 value: 37000
# Processing Area of Residence: Europe, Country: Republic of Ireland
# Filled 2020 Q1 with 2021 Q1 value: 24000
# Filled 2020 Q2 with 2021 Q2 value: 47000
# Filled 2020 Q3 with 2021 Q3 value: 247000
# Filled 2020 Q4 with 2021 Q4 value: 391000
# Processing Area of Residence: Europe, Country: Italy
# Filled 2020 Q1 with 2021 Q1 value: 10000
# Filled 2020 Q2 with 2021 Q2 value: 13000
# Filled 2020 Q3 with 2021 Q3 value: 85000
# Filled 2020 Q4 with 2021 Q4 value: 147000
# Processing Area of Residence: Europe, Country: Lithuania
# Filled 2020 Q1 with 2021 Q1 value: 2000
# Filled 2020 Q2 with 2021 Q2 value: 1000
# Filled 2020 Q3 with 2021 Q3 value: 19000
# Filled 2020 Q4 with 2021 Q4 value: 25000
# Processing Area of Residence: Europe, Country: Luxembourg
# Filled 2020 Q1 with 2021 Q1 value: 0
# Filled 2020 Q2 with 2021 Q2 value: 1000
# Filled 2020 Q3 with 2021 Q3 value: 7000
# Filled 2020 Q4 with 2021 Q4 value: 8000
# Processing Area of Residence: Europe, Country: Malta
# Filled 2020 Q1 with 2021 Q1 value: 0
# Filled 2020 Q2 with 2021 Q2 value: 1000
# Filled 2020 Q3 with 2021 Q3 value: 10000
# Filled 2020 Q4 with 2021 Q4 value: 16000
# Processing Area of Residence: Europe, Country: Netherlands
# Filled 2020 Q1 with 2021 Q1 value: 13000
# Filled 2020 Q2 with 2021 Q2 value: 13000
# Filled 2020 Q3 with 2021 Q3 value: 77000
# Filled 2020 Q4 with 2021 Q4 value: 170000
# Processing Area of Residence: Europe, Country: Norway
# Filled 2020 Q1 with 2021 Q1 value: 1000
# Filled 2020 Q2 with 2021 Q2 value: 2000
# Filled 2020 Q3 with 2021 Q3 value: 13000
# Filled 2020 Q4 with 2021 Q4 value: 60000
# Processing Area of Residence: Europe, Country: Poland
# Filled 2020 Q1 with 2021 Q1 value: 8000
# Filled 2020 Q2 with 2021 Q2 value: 10000
# Filled 2020 Q3 with 2021 Q3 value: 135000
# Filled 2020 Q4 with 2021 Q4 value: 183000
# Processing Area of Residence: Europe, Country: Portugal
# Filled 2020 Q1 with 2021 Q1 value: 3000
# Filled 2020 Q2 with 2021 Q2 value: 8000
# Filled 2020 Q3 with 2021 Q3 value: 45000
# Filled 2020 Q4 with 2021 Q4 value: 92000
# Processing Area of Residence: Europe, Country: Romania
# Filled 2020 Q1 with 2021 Q1 value: 13000
# Filled 2020 Q2 with 2021 Q2 value: 16000
# Filled 2020 Q3 with 2021 Q3 value: 62000
# Filled 2020 Q4 with 2021 Q4 value: 101000
# Processing Area of Residence: Europe, Country: Russia
# Filled 2020 Q1 with 2021 Q1 value: 2000
# Filled 2020 Q2 with 2021 Q2 value: 4000
# Filled 2020 Q3 with 2021 Q3 value: 10000
# Filled 2020 Q4 with 2021 Q4 value: 7000
# Processing Area of Residence: Europe, Country: Slovakia
# Filled 2020 Q1 with 2021 Q1 value: 0
# Filled 2020 Q2 with 2021 Q2 value: 1000
# Filled 2020 Q3 with 2021 Q3 value: 4000
# Filled 2020 Q4 with 2021 Q4 value: 6000
# Processing Area of Residence: Europe, Country: Spain
# Filled 2020 Q1 with 2021 Q1 value: 24000
# Filled 2020 Q2 with 2021 Q2 value: 25000
# Filled 2020 Q3 with 2021 Q3 value: 174000
# Filled 2020 Q4 with 2021 Q4 value: 302000
# Processing Area of Residence: Europe, Country: Sweden
# Filled 2020 Q1 with 2021 Q1 value: 2000
# Filled 2020 Q2 with 2021 Q2 value: 5000
# Filled 2020 Q3 with 2021 Q3 value: 45000
# Filled 2020 Q4 with 2021 Q4 value: 65000
# Processing Area of Residence: Europe, Country: Switzerland
# Filled 2020 Q1 with 2021 Q1 value: 2000
# Filled 2020 Q2 with 2021 Q2 value: 11000
# Filled 2020 Q3 with 2021 Q3 value: 63000
# Filled 2020 Q4 with 2021 Q4 value: 87000
# Processing Area of Residence: Europe, Country: Turkey
# Filled 2020 Q1 with 2021 Q1 value: 1000
# Filled 2020 Q2 with 2021 Q2 value: 2000
# Filled 2020 Q3 with 2021 Q3 value: 3000
# Filled 2020 Q4 with 2021 Q4 value: 24000
# Processing Area of Residence: Europe, Country: Rest of Europe
# Filled 2020 Q1 with 2021 Q1 value: 5000
# Filled 2020 Q2 with 2021 Q2 value: 10000
# Filled 2020 Q3 with 2021 Q3 value: 63000
# Filled 2020 Q4 with 2021 Q4 value: 122000
# Processing Area of Residence: Europe, Country: Total Europe
# Filled 2020 Q1 with 2021 Q1 value: 158000
# Filled 2020 Q2 with 2021 Q2 value: 242000
# Filled 2020 Q3 with 2021 Q3 value: 1528000
# Filled 2020 Q4 with 2021 Q4 value: 2904000
# Processing Area of Residence: Europe, Country: EU
# Filled 2020 Q1 with 2021 Q1 value: 147000
# Filled 2020 Q2 with 2021 Q2 value: 216000
# Filled 2020 Q3 with 2021 Q3 value: 1395000
# Filled 2020 Q4 with 2021 Q4 value: 2653000
# Processing Area of Residence: Europe, Country: EU15
# Filled 2020 Q1 with 2021 Q1 value: 111000
# Filled 2020 Q2 with 2021 Q2 value: 173000
# Filled 2020 Q3 with 2021 Q3 value: 1078000
# Filled 2020 Q4 with 2021 Q4 value: 2154000
# Processing Area of Residence: Europe, Country: EU Other
# Filled 2020 Q1 with 2021 Q1 value: 36000
# Filled 2020 Q2 with 2021 Q2 value: 42000
# Filled 2020 Q3 with 2021 Q3 value: 317000
# Filled 2020 Q4 with 2021 Q4 value: 499000
# Processing Area of Residence: Other Countries, Country: Egypt
# Filled 2020 Q1 with 2021 Q1 value: 1000
# Filled 2020 Q2 with 2021 Q2 value: 1000
# Filled 2020 Q3 with 2021 Q3 value: 2000
# Filled 2020 Q4 with 2021 Q4 value: 4000
# Processing Area of Residence: Other Countries, Country: Morocco
# Filled 2020 Q1 with 2021 Q1 value: 0
# Filled 2020 Q2 with 2021 Q2 value: 0
# Filled 2020 Q3 with 2021 Q3 value: 1000
# Filled 2020 Q4 with 2021 Q4 value: 1000
# Processing Area of Residence: Other Countries, Country: Tunisia
# Filled 2020 Q1 with 2021 Q1 value: 0
# Filled 2020 Q2 with 2021 Q2 value: 0
# Filled 2020 Q3 with 2021 Q3 value: 0
# Filled 2020 Q4 with 2021 Q4 value: 1000
# Processing Area of Residence: Other Countries, Country: Other North Africa
# Filled 2020 Q1 with 2021 Q1 value: 0
# Filled 2020 Q2 with 2021 Q2 value: 0
# Filled 2020 Q3 with 2021 Q3 value: 1000
# Filled 2020 Q4 with 2021 Q4 value: 0
# Processing Area of Residence: Other Countries, Country: South Africa
# Filled 2020 Q1 with 2021 Q1 value: 2000
# Filled 2020 Q2 with 2021 Q2 value: 2000
# Filled 2020 Q3 with 2021 Q3 value: 3000
# Filled 2020 Q4 with 2021 Q4 value: 10000
# Processing Area of Residence: Other Countries, Country: Nigeria
# Filled 2020 Q1 with 2021 Q1 value: 6000
# Filled 2020 Q2 with 2021 Q2 value: 7000
# Filled 2020 Q3 with 2021 Q3 value: 36000
# Filled 2020 Q4 with 2021 Q4 value: 32000
# Processing Area of Residence: Other Countries, Country: Other Africa
# Filled 2020 Q1 with 2021 Q1 value: 2000
# Filled 2020 Q2 with 2021 Q2 value: 2000
# Filled 2020 Q3 with 2021 Q3 value: 7000
# Filled 2020 Q4 with 2021 Q4 value: 15000
# Processing Area of Residence: Other Countries, Country: Israel
# Filled 2020 Q1 with 2021 Q1 value: 0
# Filled 2020 Q2 with 2021 Q2 value: 5000
# Filled 2020 Q3 with 2021 Q3 value: 30000
# Filled 2020 Q4 with 2021 Q4 value: 35000
# Processing Area of Residence: Other Countries, Country: United Arab Emirates
# Filled 2020 Q1 with 2021 Q1 value: 4000
# Filled 2020 Q2 with 2021 Q2 value: 3000
# Filled 2020 Q3 with 2021 Q3 value: 22000
# Filled 2020 Q4 with 2021 Q4 value: 63000
# Processing Area of Residence: Other Countries, Country: Other Middle East
# Filled 2020 Q1 with 2021 Q1 value: 6000
# Filled 2020 Q2 with 2021 Q2 value: 9000
# Filled 2020 Q3 with 2021 Q3 value: 48000
# Filled 2020 Q4 with 2021 Q4 value: 95000
# Processing Area of Residence: Other Countries, Country: Hong Kong (China)
# Filled 2020 Q1 with 2021 Q1 value: 1000
# Filled 2020 Q2 with 2021 Q2 value: 1000
# Filled 2020 Q3 with 2021 Q3 value: 4000
# Filled 2020 Q4 with 2021 Q4 value: 6000
# Processing Area of Residence: Other Countries, Country: Other China
# Filled 2020 Q1 with 2021 Q1 value: 1000
# Filled 2020 Q2 with 2021 Q2 value: 4000
# Filled 2020 Q3 with 2021 Q3 value: 8000
# Filled 2020 Q4 with 2021 Q4 value: 3000
# Processing Area of Residence: Other Countries, Country: India
# Filled 2020 Q1 with 2021 Q1 value: 6000
# Filled 2020 Q2 with 2021 Q2 value: 3000
# Filled 2020 Q3 with 2021 Q3 value: 15000
# Filled 2020 Q4 with 2021 Q4 value: 33000
# Processing Area of Residence: Other Countries, Country: Japan
# Filled 2020 Q1 with 2021 Q1 value: 2000
# Filled 2020 Q2 with 2021 Q2 value: 2000
# Filled 2020 Q3 with 2021 Q3 value: 2000
# Filled 2020 Q4 with 2021 Q4 value: 5000
# Processing Area of Residence: Other Countries, Country: Pakistan
# Filled 2020 Q1 with 2021 Q1 value: 4000
# Filled 2020 Q2 with 2021 Q2 value: 1000
# Filled 2020 Q3 with 2021 Q3 value: 3000
# Filled 2020 Q4 with 2021 Q4 value: 12000
# Processing Area of Residence: Other Countries, Country: Sri Lanka
# Filled 2020 Q1 with 2021 Q1 value: 0
# Filled 2020 Q2 with 2021 Q2 value: 0
# Filled 2020 Q3 with 2021 Q3 value: 0
# Filled 2020 Q4 with 2021 Q4 value: 0
# Processing Area of Residence: Other Countries, Country: Thailand
# Filled 2020 Q1 with 2021 Q1 value: 1000
# Filled 2020 Q2 with 2021 Q2 value: 1000
# Filled 2020 Q3 with 2021 Q3 value: 2000
# Filled 2020 Q4 with 2021 Q4 value: 1000
# Processing Area of Residence: Other Countries, Country: Other Asia
# Filled 2020 Q1 with 2021 Q1 value: 4000
# Filled 2020 Q2 with 2021 Q2 value: 4000
# Filled 2020 Q3 with 2021 Q3 value: 13000
# Filled 2020 Q4 with 2021 Q4 value: 54000
# Processing Area of Residence: Other Countries, Country: Australia
# Filled 2020 Q1 with 2021 Q1 value: 1000
# Filled 2020 Q2 with 2021 Q2 value: 1000
# Filled 2020 Q3 with 2021 Q3 value: 3000
# Filled 2020 Q4 with 2021 Q4 value: 19000
# Processing Area of Residence: Other Countries, Country: New Zealand
# Filled 2020 Q1 with 2021 Q1 value: 1000
# Filled 2020 Q2 with 2021 Q2 value: 1000
# Filled 2020 Q3 with 2021 Q3 value: 3000
# Filled 2020 Q4 with 2021 Q4 value: 5000
# Processing Area of Residence: Other Countries, Country: Barbados
# Filled 2020 Q1 with 2021 Q1 value: 0
# Filled 2020 Q2 with 2021 Q2 value: 0
# Filled 2020 Q3 with 2021 Q3 value: 1000
# Filled 2020 Q4 with 2021 Q4 value: 1000
# Processing Area of Residence: Other Countries, Country: Jamaica
# Filled 2020 Q1 with 2021 Q1 value: 0
# Filled 2020 Q2 with 2021 Q2 value: 0
# Filled 2020 Q3 with 2021 Q3 value: 0
# Filled 2020 Q4 with 2021 Q4 value: 1000
# Processing Area of Residence: Other Countries, Country: Other Caribbean
# Filled 2020 Q1 with 2021 Q1 value: 2000
# Filled 2020 Q2 with 2021 Q2 value: 2000
# Filled 2020 Q3 with 2021 Q3 value: 5000
# Filled 2020 Q4 with 2021 Q4 value: 10000
# Processing Area of Residence: Other Countries, Country: Brazil
# Filled 2020 Q1 with 2021 Q1 value: 3000
# Filled 2020 Q2 with 2021 Q2 value: 1000
# Filled 2020 Q3 with 2021 Q3 value: 3000
# Filled 2020 Q4 with 2021 Q4 value: 13000
# Processing Area of Residence: Other Countries, Country: Mexico
# Filled 2020 Q1 with 2021 Q1 value: 0
# Filled 2020 Q2 with 2021 Q2 value: 1000
# Filled 2020 Q3 with 2021 Q3 value: 5000
# Filled 2020 Q4 with 2021 Q4 value: 3000
# Processing Area of Residence: Other Countries, Country: Other Central & Sth. America
# Filled 2020 Q1 with 2021 Q1 value: 6000
# Filled 2020 Q2 with 2021 Q2 value: 1000
# Filled 2020 Q3 with 2021 Q3 value: 4000
# Filled 2020 Q4 with 2021 Q4 value: 9000
# Processing Area of Residence: Other Countries, Country: Rest of the World
# Filled 2020 Q1 with 2021 Q1 value: 0
# Filled 2020 Q2 with 2021 Q2 value: 0
# Filled 2020 Q3 with 2021 Q3 value: 0
# Filled 2020 Q4 with 2021 Q4 value: 0
# Processing Area of Residence: Other Countries, Country: Total Other Countries
# Filled 2020 Q1 with 2021 Q1 value: 56000
# Filled 2020 Q2 with 2021 Q2 value: 53000
# Filled 2020 Q3 with 2021 Q3 value: 222000
# Filled 2020 Q4 with 2021 Q4 value: 428000
# Processing Area of Residence: Total World, Country: Total World
# Filled 2020 Q1 with 2021 Q1 value: 245000
# Filled 2020 Q2 with 2021 Q2 value: 346000
# Filled 2020 Q3 with 2021 Q3 value: 2040000
# Filled 2020 Q4 with 2021 Q4 value: 3753000
# Processing Area of Residence: North America, Country: Canada
# Filled 2020 Q1 with 2021 Q1 value: 2
# Filled 2020 Q2 with 2021 Q2 value: 9
# Filled 2020 Q3 with 2021 Q3 value: 53
# Filled 2020 Q4 with 2021 Q4 value: 83
# Processing Area of Residence: North America, Country: USA
# Filled 2020 Q1 with 2021 Q1 value: 29
# Filled 2020 Q2 with 2021 Q2 value: 59
# Filled 2020 Q3 with 2021 Q3 value: 276
# Filled 2020 Q4 with 2021 Q4 value: 420
# Processing Area of Residence: North America, Country: Total North America
# Filled 2020 Q1 with 2021 Q1 value: 31
# Filled 2020 Q2 with 2021 Q2 value: 68
# Filled 2020 Q3 with 2021 Q3 value: 329
# Filled 2020 Q4 with 2021 Q4 value: 504
# Processing Area of Residence: Europe, Country: Austria
# Filled 2020 Q1 with 2021 Q1 value: 1
# Filled 2020 Q2 with 2021 Q2 value: 4
# Filled 2020 Q3 with 2021 Q3 value: 12
# Filled 2020 Q4 with 2021 Q4 value: 12
# Processing Area of Residence: Europe, Country: Belgium
# Filled 2020 Q1 with 2021 Q1 value: 1
# Filled 2020 Q2 with 2021 Q2 value: 7
# Filled 2020 Q3 with 2021 Q3 value: 18
# Filled 2020 Q4 with 2021 Q4 value: 94
# Processing Area of Residence: Europe, Country: Bulgaria
# Filled 2020 Q1 with 2021 Q1 value: 10
# Filled 2020 Q2 with 2021 Q2 value: 4
# Filled 2020 Q3 with 2021 Q3 value: 11
# Filled 2020 Q4 with 2021 Q4 value: 12
# Processing Area of Residence: Europe, Country: Czech Republic
# Filled 2020 Q1 with 2021 Q1 value: 0
# Filled 2020 Q2 with 2021 Q2 value: 3
# Filled 2020 Q3 with 2021 Q3 value: 7
# Filled 2020 Q4 with 2021 Q4 value: 10
# Processing Area of Residence: Europe, Country: Cyprus
# Filled 2020 Q1 with 2021 Q1 value: 0
# Filled 2020 Q2 with 2021 Q2 value: 2
# Filled 2020 Q3 with 2021 Q3 value: 15
# Filled 2020 Q4 with 2021 Q4 value: 16
# Processing Area of Residence: Europe, Country: Denmark
# Filled 2020 Q1 with 2021 Q1 value: 3
# Filled 2020 Q2 with 2021 Q2 value: 4
# Filled 2020 Q3 with 2021 Q3 value: 16
# Filled 2020 Q4 with 2021 Q4 value: 39
# Processing Area of Residence: Europe, Country: Finland
# Filled 2020 Q1 with 2021 Q1 value: 0
# Filled 2020 Q2 with 2021 Q2 value: 2
# Filled 2020 Q3 with 2021 Q3 value: 6
# Filled 2020 Q4 with 2021 Q4 value: 10
# Processing Area of Residence: Europe, Country: France
# Filled 2020 Q1 with 2021 Q1 value: 12
# Filled 2020 Q2 with 2021 Q2 value: 28
# Filled 2020 Q3 with 2021 Q3 value: 74
# Filled 2020 Q4 with 2021 Q4 value: 307
# Processing Area of Residence: Europe, Country: Germany
# Filled 2020 Q1 with 2021 Q1 value: 8
# Filled 2020 Q2 with 2021 Q2 value: 21
# Filled 2020 Q3 with 2021 Q3 value: 82
# Filled 2020 Q4 with 2021 Q4 value: 125
# Processing Area of Residence: Europe, Country: Greece
# Filled 2020 Q1 with 2021 Q1 value: 10
# Filled 2020 Q2 with 2021 Q2 value: 3
# Filled 2020 Q3 with 2021 Q3 value: 27
# Filled 2020 Q4 with 2021 Q4 value: 32
# Processing Area of Residence: Europe, Country: Hungary
# Filled 2020 Q1 with 2021 Q1 value: 1
# Filled 2020 Q2 with 2021 Q2 value: 1
# Filled 2020 Q3 with 2021 Q3 value: 5
# Filled 2020 Q4 with 2021 Q4 value: 14
# Processing Area of Residence: Europe, Country: Republic of Ireland
# Filled 2020 Q1 with 2021 Q1 value: 13
# Filled 2020 Q2 with 2021 Q2 value: 30
# Filled 2020 Q3 with 2021 Q3 value: 102
# Filled 2020 Q4 with 2021 Q4 value: 149
# Processing Area of Residence: Europe, Country: Italy
# Filled 2020 Q1 with 2021 Q1 value: 11
# Filled 2020 Q2 with 2021 Q2 value: 15
# Filled 2020 Q3 with 2021 Q3 value: 61
# Filled 2020 Q4 with 2021 Q4 value: 87
# Processing Area of Residence: Europe, Country: Lithuania
# Filled 2020 Q1 with 2021 Q1 value: 0
# Filled 2020 Q2 with 2021 Q2 value: 1
# Filled 2020 Q3 with 2021 Q3 value: 7
# Filled 2020 Q4 with 2021 Q4 value: 11
# Processing Area of Residence: Europe, Country: Luxembourg
# Filled 2020 Q1 with 2021 Q1 value: 0
# Filled 2020 Q2 with 2021 Q2 value: 1
# Filled 2020 Q3 with 2021 Q3 value: 5
# Filled 2020 Q4 with 2021 Q4 value: 5
# Processing Area of Residence: Europe, Country: Malta
# Filled 2020 Q1 with 2021 Q1 value: 0
# Filled 2020 Q2 with 2021 Q2 value: 2
# Filled 2020 Q3 with 2021 Q3 value: 9
# Filled 2020 Q4 with 2021 Q4 value: 34
# Processing Area of Residence: Europe, Country: Netherlands
# Filled 2020 Q1 with 2021 Q1 value: 3
# Filled 2020 Q2 with 2021 Q2 value: 12
# Filled 2020 Q3 with 2021 Q3 value: 44
# Filled 2020 Q4 with 2021 Q4 value: 86
# Processing Area of Residence: Europe, Country: Norway
# Filled 2020 Q1 with 2021 Q1 value: 1
# Filled 2020 Q2 with 2021 Q2 value: 4
# Filled 2020 Q3 with 2021 Q3 value: 8
# Filled 2020 Q4 with 2021 Q4 value: 51
# Processing Area of Residence: Europe, Country: Poland
# Filled 2020 Q1 with 2021 Q1 value: 8
# Filled 2020 Q2 with 2021 Q2 value: 11
# Filled 2020 Q3 with 2021 Q3 value: 43
# Filled 2020 Q4 with 2021 Q4 value: 47
# Processing Area of Residence: Europe, Country: Portugal
# Filled 2020 Q1 with 2021 Q1 value: 2
# Filled 2020 Q2 with 2021 Q2 value: 7
# Filled 2020 Q3 with 2021 Q3 value: 27
# Filled 2020 Q4 with 2021 Q4 value: 38
# Processing Area of Residence: Europe, Country: Romania
# Filled 2020 Q1 with 2021 Q1 value: 21
# Filled 2020 Q2 with 2021 Q2 value: 17
# Filled 2020 Q3 with 2021 Q3 value: 36
# Filled 2020 Q4 with 2021 Q4 value: 41
# Processing Area of Residence: Europe, Country: Russia
# Filled 2020 Q1 with 2021 Q1 value: 2
# Filled 2020 Q2 with 2021 Q2 value: 4
# Filled 2020 Q3 with 2021 Q3 value: 7
# Filled 2020 Q4 with 2021 Q4 value: 6
# Processing Area of Residence: Europe, Country: Slovakia
# Filled 2020 Q1 with 2021 Q1 value: 0
# Filled 2020 Q2 with 2021 Q2 value: 1
# Filled 2020 Q3 with 2021 Q3 value: 5
# Filled 2020 Q4 with 2021 Q4 value: 4
# Processing Area of Residence: Europe, Country: Spain
# Filled 2020 Q1 with 2021 Q1 value: 21
# Filled 2020 Q2 with 2021 Q2 value: 25
# Filled 2020 Q3 with 2021 Q3 value: 97
# Filled 2020 Q4 with 2021 Q4 value: 155
# Processing Area of Residence: Europe, Country: Sweden
# Filled 2020 Q1 with 2021 Q1 value: 2
# Filled 2020 Q2 with 2021 Q2 value: 4
# Filled 2020 Q3 with 2021 Q3 value: 27
# Filled 2020 Q4 with 2021 Q4 value: 46
# Processing Area of Residence: Europe, Country: Switzerland
# Filled 2020 Q1 with 2021 Q1 value: 3
# Filled 2020 Q2 with 2021 Q2 value: 12
# Filled 2020 Q3 with 2021 Q3 value: 65
# Filled 2020 Q4 with 2021 Q4 value: 63
# Processing Area of Residence: Europe, Country: Turkey
# Filled 2020 Q1 with 2021 Q1 value: 2
# Filled 2020 Q2 with 2021 Q2 value: 4
# Filled 2020 Q3 with 2021 Q3 value: 3
# Filled 2020 Q4 with 2021 Q4 value: 25
# Processing Area of Residence: Europe, Country: Rest of Europe
# Filled 2020 Q1 with 2021 Q1 value: 8
# Filled 2020 Q2 with 2021 Q2 value: 20
# Filled 2020 Q3 with 2021 Q3 value: 63
# Filled 2020 Q4 with 2021 Q4 value: 109
# Processing Area of Residence: Europe, Country: Total Europe
# Filled 2020 Q1 with 2021 Q1 value: 143
# Filled 2020 Q2 with 2021 Q2 value: 247
# Filled 2020 Q3 with 2021 Q3 value: 881
# Filled 2020 Q4 with 2021 Q4 value: 1626
# Processing Area of Residence: Europe, Country: EU
# Filled 2020 Q1 with 2021 Q1 value: 127
# Filled 2020 Q2 with 2021 Q2 value: 205
# Filled 2020 Q3 with 2021 Q3 value: 739
# Filled 2020 Q4 with 2021 Q4 value: 1393
# Processing Area of Residence: Europe, Country: EU15
# Filled 2020 Q1 with 2021 Q1 value: 86
# Filled 2020 Q2 with 2021 Q2 value: 162
# Filled 2020 Q3 with 2021 Q3 value: 597
# Filled 2020 Q4 with 2021 Q4 value: 1185
# Processing Area of Residence: Europe, Country: EU Other
# Filled 2020 Q1 with 2021 Q1 value: 41
# Filled 2020 Q2 with 2021 Q2 value: 44
# Filled 2020 Q3 with 2021 Q3 value: 142
# Filled 2020 Q4 with 2021 Q4 value: 208
# Processing Area of Residence: Other Countries, Country: Egypt
# Filled 2020 Q1 with 2021 Q1 value: 1
# Filled 2020 Q2 with 2021 Q2 value: 2
# Filled 2020 Q3 with 2021 Q3 value: 4
# Filled 2020 Q4 with 2021 Q4 value: 15
# Processing Area of Residence: Other Countries, Country: Morocco
# Filled 2020 Q1 with 2021 Q1 value: 0
# Filled 2020 Q2 with 2021 Q2 value: 0
# Filled 2020 Q3 with 2021 Q3 value: 3
# Filled 2020 Q4 with 2021 Q4 value: 2
# Processing Area of Residence: Other Countries, Country: Tunisia
# Filled 2020 Q1 with 2021 Q1 value: 0
# Filled 2020 Q2 with 2021 Q2 value: 1
# Filled 2020 Q3 with 2021 Q3 value: 0
# Filled 2020 Q4 with 2021 Q4 value: 0
# Processing Area of Residence: Other Countries, Country: Other North Africa
# Filled 2020 Q1 with 2021 Q1 value: 1
# Filled 2020 Q2 with 2021 Q2 value: 1
# Filled 2020 Q3 with 2021 Q3 value: 1
# Filled 2020 Q4 with 2021 Q4 value: 0
# Processing Area of Residence: Other Countries, Country: South Africa
# Filled 2020 Q1 with 2021 Q1 value: 3
# Filled 2020 Q2 with 2021 Q2 value: 3
# Filled 2020 Q3 with 2021 Q3 value: 6
# Filled 2020 Q4 with 2021 Q4 value: 14
# Processing Area of Residence: Other Countries, Country: Nigeria
# Filled 2020 Q1 with 2021 Q1 value: 15
# Filled 2020 Q2 with 2021 Q2 value: 20
# Filled 2020 Q3 with 2021 Q3 value: 64
# Filled 2020 Q4 with 2021 Q4 value: 75
# Processing Area of Residence: Other Countries, Country: Other Africa
# Filled 2020 Q1 with 2021 Q1 value: 2
# Filled 2020 Q2 with 2021 Q2 value: 9
# Filled 2020 Q3 with 2021 Q3 value: 14
# Filled 2020 Q4 with 2021 Q4 value: 23
# Processing Area of Residence: Other Countries, Country: Israel
# Filled 2020 Q1 with 2021 Q1 value: 0
# Filled 2020 Q2 with 2021 Q2 value: 4
# Filled 2020 Q3 with 2021 Q3 value: 34
# Filled 2020 Q4 with 2021 Q4 value: 38
# Processing Area of Residence: Other Countries, Country: United Arab Emirates
# Filled 2020 Q1 with 2021 Q1 value: 8
# Filled 2020 Q2 with 2021 Q2 value: 12
# Filled 2020 Q3 with 2021 Q3 value: 49
# Filled 2020 Q4 with 2021 Q4 value: 131
# Processing Area of Residence: Other Countries, Country: Other Middle East
# Filled 2020 Q1 with 2021 Q1 value: 21
# Filled 2020 Q2 with 2021 Q2 value: 95
# Filled 2020 Q3 with 2021 Q3 value: 179
# Filled 2020 Q4 with 2021 Q4 value: 297
# Processing Area of Residence: Other Countries, Country: Hong Kong (China)
# Filled 2020 Q1 with 2021 Q1 value: 5
# Filled 2020 Q2 with 2021 Q2 value: 7
# Filled 2020 Q3 with 2021 Q3 value: 10
# Filled 2020 Q4 with 2021 Q4 value: 22
# Processing Area of Residence: Other Countries, Country: Other China
# Filled 2020 Q1 with 2021 Q1 value: 6
# Filled 2020 Q2 with 2021 Q2 value: 44
# Filled 2020 Q3 with 2021 Q3 value: 80
# Filled 2020 Q4 with 2021 Q4 value: 16
# Processing Area of Residence: Other Countries, Country: India
# Filled 2020 Q1 with 2021 Q1 value: 8
# Filled 2020 Q2 with 2021 Q2 value: 5
# Filled 2020 Q3 with 2021 Q3 value: 30
# Filled 2020 Q4 with 2021 Q4 value: 72
# Processing Area of Residence: Other Countries, Country: Japan
# Filled 2020 Q1 with 2021 Q1 value: 5
# Filled 2020 Q2 with 2021 Q2 value: 3
# Filled 2020 Q3 with 2021 Q3 value: 3
# Filled 2020 Q4 with 2021 Q4 value: 8
# Processing Area of Residence: Other Countries, Country: Pakistan
# Filled 2020 Q1 with 2021 Q1 value: 5
# Filled 2020 Q2 with 2021 Q2 value: 2
# Filled 2020 Q3 with 2021 Q3 value: 2
# Filled 2020 Q4 with 2021 Q4 value: 12
# Processing Area of Residence: Other Countries, Country: Sri Lanka
# Filled 2020 Q1 with 2021 Q1 value: 2
# Filled 2020 Q2 with 2021 Q2 value: 0
# Filled 2020 Q3 with 2021 Q3 value: 0
# Filled 2020 Q4 with 2021 Q4 value: 0
# Processing Area of Residence: Other Countries, Country: Thailand
# Filled 2020 Q1 with 2021 Q1 value: 4
# Filled 2020 Q2 with 2021 Q2 value: 2
# Filled 2020 Q3 with 2021 Q3 value: 6
# Filled 2020 Q4 with 2021 Q4 value: 1
# Processing Area of Residence: Other Countries, Country: Other Asia
# Filled 2020 Q1 with 2021 Q1 value: 9
# Filled 2020 Q2 with 2021 Q2 value: 7
# Filled 2020 Q3 with 2021 Q3 value: 40
# Filled 2020 Q4 with 2021 Q4 value: 93
# Processing Area of Residence: Other Countries, Country: Australia
# Filled 2020 Q1 with 2021 Q1 value: 1
# Filled 2020 Q2 with 2021 Q2 value: 5
# Filled 2020 Q3 with 2021 Q3 value: 5
# Filled 2020 Q4 with 2021 Q4 value: 24
# Processing Area of Residence: Other Countries, Country: New Zealand
# Filled 2020 Q1 with 2021 Q1 value: 6
# Filled 2020 Q2 with 2021 Q2 value: 1
# Filled 2020 Q3 with 2021 Q3 value: 6
# Filled 2020 Q4 with 2021 Q4 value: 4
# Processing Area of Residence: Other Countries, Country: Barbados
# Filled 2020 Q1 with 2021 Q1 value: 0
# Filled 2020 Q2 with 2021 Q2 value: 0
# Filled 2020 Q3 with 2021 Q3 value: 1
# Filled 2020 Q4 with 2021 Q4 value: 1
# Processing Area of Residence: Other Countries, Country: Jamaica
# Filled 2020 Q1 with 2021 Q1 value: 0
# Filled 2020 Q2 with 2021 Q2 value: 0
# Filled 2020 Q3 with 2021 Q3 value: 0
# Filled 2020 Q4 with 2021 Q4 value: 2
# Processing Area of Residence: Other Countries, Country: Other Caribbean
# Filled 2020 Q1 with 2021 Q1 value: 2
# Filled 2020 Q2 with 2021 Q2 value: 3
# Filled 2020 Q3 with 2021 Q3 value: 8
# Filled 2020 Q4 with 2021 Q4 value: 10
# Processing Area of Residence: Other Countries, Country: Brazil
# Filled 2020 Q1 with 2021 Q1 value: 3
# Filled 2020 Q2 with 2021 Q2 value: 2
# Filled 2020 Q3 with 2021 Q3 value: 3
# Filled 2020 Q4 with 2021 Q4 value: 17
# Processing Area of Residence: Other Countries, Country: Mexico
# Filled 2020 Q1 with 2021 Q1 value: 1
# Filled 2020 Q2 with 2021 Q2 value: 1
# Filled 2020 Q3 with 2021 Q3 value: 6
# Filled 2020 Q4 with 2021 Q4 value: 6
# Processing Area of Residence: Other Countries, Country: Other Central & Sth. America
# Filled 2020 Q1 with 2021 Q1 value: 4
# Filled 2020 Q2 with 2021 Q2 value: 1
# Filled 2020 Q3 with 2021 Q3 value: 8
# Filled 2020 Q4 with 2021 Q4 value: 24
# Processing Area of Residence: Other Countries, Country: Rest of the World
# Filled 2020 Q1 with 2021 Q1 value: 0
# Filled 2020 Q2 with 2021 Q2 value: 0
# Filled 2020 Q3 with 2021 Q3 value: 1
# Filled 2020 Q4 with 2021 Q4 value: 1
# Processing Area of Residence: Other Countries, Country: Total Other Countries
# Filled 2020 Q1 with 2021 Q1 value: 113
# Filled 2020 Q2 with 2021 Q2 value: 231
# Filled 2020 Q3 with 2021 Q3 value: 565
# Filled 2020 Q4 with 2021 Q4 value: 909
# Processing Area of Residence: Total World, Country: Total World
# Filled 2020 Q1 with 2021 Q1 value: 287
# Filled 2020 Q2 with 2021 Q2 value: 545
# Filled 2020 Q3 with 2021 Q3 value: 1775
# Filled 2020 Q4 with 2021 Q4 value: 3039
# Recalculated 2020 for Canada in North America: 128000
# Recalculated 2020 for Canada in North America: 147
# Recalculated 2020 for USA in North America: 663000
# Recalculated 2020 for USA in North America: 784
# Recalculated 2020 for Total North America in North America: 792000
# Recalculated 2020 for Total North America in North America: 932
# Recalculated 2020 for Austria in Europe: 56000
# Recalculated 2020 for Austria in Europe: 29
# Recalculated 2020 for Belgium in Europe: 159000
# Recalculated 2020 for Belgium in Europe: 120
# Recalculated 2020 for Bulgaria in Europe: 57000
# Recalculated 2020 for Bulgaria in Europe: 37
# Recalculated 2020 for Czech Republic in Europe: 55000
# Recalculated 2020 for Czech Republic in Europe: 20
# Recalculated 2020 for Cyprus in Europe: 41000
# Recalculated 2020 for Cyprus in Europe: 33
# Recalculated 2020 for Denmark in Europe: 101000
# Recalculated 2020 for Denmark in Europe: 62
# Recalculated 2020 for Finland in Europe: 17000
# Recalculated 2020 for Finland in Europe: 18
# Recalculated 2020 for France in Europe: 678000
# Recalculated 2020 for France in Europe: 421
# Recalculated 2020 for Germany in Europe: 390000
# Recalculated 2020 for Germany in Europe: 236
# Recalculated 2020 for Greece in Europe: 72000
# Recalculated 2020 for Greece in Europe: 72
# Recalculated 2020 for Hungary in Europe: 58000
# Recalculated 2020 for Hungary in Europe: 21
# Recalculated 2020 for Republic of Ireland in Europe: 709000
# Recalculated 2020 for Republic of Ireland in Europe: 294
# Recalculated 2020 for Italy in Europe: 255000
# Recalculated 2020 for Italy in Europe: 174
# Recalculated 2020 for Lithuania in Europe: 47000
# Recalculated 2020 for Lithuania in Europe: 19
# Recalculated 2020 for Luxembourg in Europe: 16000
# Recalculated 2020 for Luxembourg in Europe: 11
# Recalculated 2020 for Malta in Europe: 27000
# Recalculated 2020 for Malta in Europe: 45
# Recalculated 2020 for Netherlands in Europe: 273000
# Recalculated 2020 for Netherlands in Europe: 145
# Recalculated 2020 for Norway in Europe: 76000
# Recalculated 2020 for Norway in Europe: 64
# Recalculated 2020 for Poland in Europe: 336000
# Recalculated 2020 for Poland in Europe: 109
# Recalculated 2020 for Portugal in Europe: 148000
# Recalculated 2020 for Portugal in Europe: 74
# Recalculated 2020 for Romania in Europe: 192000
# Recalculated 2020 for Romania in Europe: 115
# Recalculated 2020 for Russia in Europe: 23000
# Recalculated 2020 for Russia in Europe: 19
# Recalculated 2020 for Slovakia in Europe: 11000
# Recalculated 2020 for Slovakia in Europe: 10
# Recalculated 2020 for Spain in Europe: 525000
# Recalculated 2020 for Spain in Europe: 298
# Recalculated 2020 for Sweden in Europe: 117000
# Recalculated 2020 for Sweden in Europe: 79
# Recalculated 2020 for Switzerland in Europe: 163000
# Recalculated 2020 for Switzerland in Europe: 143
# Recalculated 2020 for Turkey in Europe: 30000
# Recalculated 2020 for Turkey in Europe: 34
# Recalculated 2020 for Rest of Europe in Europe: 200000
# Recalculated 2020 for Rest of Europe in Europe: 200
# Recalculated 2020 for Total Europe in Europe: 4832000
# Recalculated 2020 for Total Europe in Europe: 2897
# Recalculated 2020 for EU in Europe: 4411000
# Recalculated 2020 for EU in Europe: 2464
# Recalculated 2020 for EU15 in Europe: 3516000
# Recalculated 2020 for EU15 in Europe: 2030
# Recalculated 2020 for EU Other in Europe: 894000
# Recalculated 2020 for EU Other in Europe: 435
# Recalculated 2020 for Egypt in Other Countries: 8000
# Recalculated 2020 for Egypt in Other Countries: 22
# Recalculated 2020 for Morocco in Other Countries: 2000
# Recalculated 2020 for Morocco in Other Countries: 5
# Recalculated 2020 for Tunisia in Other Countries: 1000
# Recalculated 2020 for Tunisia in Other Countries: 1
# Recalculated 2020 for Other North Africa in Other Countries: 1000
# Recalculated 2020 for Other North Africa in Other Countries: 3
# Recalculated 2020 for South Africa in Other Countries: 17000
# Recalculated 2020 for South Africa in Other Countries: 26
# Recalculated 2020 for Nigeria in Other Countries: 81000
# Recalculated 2020 for Nigeria in Other Countries: 174
# Recalculated 2020 for Other Africa in Other Countries: 26000
# Recalculated 2020 for Other Africa in Other Countries: 48
# Recalculated 2020 for Israel in Other Countries: 70000
# Recalculated 2020 for Israel in Other Countries: 76
# Recalculated 2020 for United Arab Emirates in Other Countries: 92000
# Recalculated 2020 for United Arab Emirates in Other Countries: 200
# Recalculated 2020 for Other Middle East in Other Countries: 158000
# Recalculated 2020 for Other Middle East in Other Countries: 592
# Recalculated 2020 for Hong Kong (China) in Other Countries: 12000
# Recalculated 2020 for Hong Kong (China) in Other Countries: 44
# Recalculated 2020 for Other China in Other Countries: 16000
# Recalculated 2020 for Other China in Other Countries: 146
# Recalculated 2020 for India in Other Countries: 57000
# Recalculated 2020 for India in Other Countries: 115
# Recalculated 2020 for Japan in Other Countries: 11000
# Recalculated 2020 for Japan in Other Countries: 19
# Recalculated 2020 for Pakistan in Other Countries: 20000
# Recalculated 2020 for Pakistan in Other Countries: 21
# Recalculated 2020 for Sri Lanka in Other Countries: 0
# Recalculated 2020 for Sri Lanka in Other Countries: 2
# Recalculated 2020 for Thailand in Other Countries: 5000
# Recalculated 2020 for Thailand in Other Countries: 13
# Recalculated 2020 for Other Asia in Other Countries: 75000
# Recalculated 2020 for Other Asia in Other Countries: 149
# Recalculated 2020 for Australia in Other Countries: 24000
# Recalculated 2020 for Australia in Other Countries: 35
# Recalculated 2020 for New Zealand in Other Countries: 10000
# Recalculated 2020 for New Zealand in Other Countries: 17
# Recalculated 2020 for Barbados in Other Countries: 2000
# Recalculated 2020 for Barbados in Other Countries: 2
# Recalculated 2020 for Jamaica in Other Countries: 1000
# Recalculated 2020 for Jamaica in Other Countries: 2
# Recalculated 2020 for Other Caribbean in Other Countries: 19000
# Recalculated 2020 for Other Caribbean in Other Countries: 23
# Recalculated 2020 for Brazil in Other Countries: 20000
# Recalculated 2020 for Brazil in Other Countries: 25
# Recalculated 2020 for Mexico in Other Countries: 9000
# Recalculated 2020 for Mexico in Other Countries: 14
# Recalculated 2020 for Other Central & Sth. America in Other Countries: 20000
# Recalculated 2020 for Other Central & Sth. America in Other Countries: 37
# Recalculated 2020 for Rest of the World in Other Countries: 0
# Recalculated 2020 for Rest of the World in Other Countries: 2
# Recalculated 2020 for Total Other Countries in Other Countries: 759000
# Recalculated 2020 for Total Other Countries in Other Countries: 1818
# Recalculated 2020 for Total World in Total World: 6384000
# Recalculated 2020 for Total World in Total World: 5646
# After Recalculating - Entire DataFrame for 2020:
#     Area of Residence                       Country     Year  \
# 64      North America                        Canada     2020
# 65      North America                           USA     2020
# 66      North America           Total North America     2020
# 67             Europe                       Austria     2020
# 68             Europe                       Belgium     2020
# ..                ...                           ...      ...
# 827   Other Countries                        Mexico  2020 Q4
# 828   Other Countries  Other Central & Sth. America  2020 Q4
# 829   Other Countries             Rest of the World  2020 Q4
# 830   Other Countries         Total Other Countries  2020 Q4
# 831       Total World                   Total World  2020 Q4
#
#     Visits by Country Spendings by Country
# 64             128000                  147
# 65             663000                  784
# 66             792000                  932
# 67              56000                   29
# 68             159000                  120
# ..                ...                  ...
# 827              3000                    6
# 828              9000                   24
# 829                 0                    1
# 830            428000                  909
# 831           3753000                 3039
#
# [320 rows x 5 columns]
